# %% [markdown]
# ## NAME: HIRANYA BANDI

# %% [markdown]
# ### PROBLEM STATEMENT: Linear Regression model to predict expected CTC of an employee

# %% [markdown]
# #### Importing the libraries

# %%
import pandas as pd #arranging the given dataset into a table
import seaborn as sns
import numpy as np   #mathematical operations
import matplotlib.pyplot as plt # data visualization
from sklearn import linear_model #statistical modeling
regr = linear_model.LinearRegression()
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %% [markdown]
# ### Reading the dataset

# %%
original_data = pd.read_excel("Data_file.xlsx", skiprows=2)
test_data = pd.read_excel("Test_data_file.xlsx", usecols="A:L")
data = original_data

# %% [markdown]
# ### dropping a column

# %%
data.drop('S.No.', axis = 1, inplace = True)

# %% [markdown]
# #### head-top row of a dataframe

# %%
data.head()
# Out:
#   College       Role  City type  Previous CTC  Previous job changes  \
# 0  Tier 1    Manager  Non-Metro         55523                     3
# 1  Tier 2  Executive      Metro         57081                     1
# 2  Tier 2  Executive      Metro         60347                     2
# 3  Tier 3  Executive      Metro         49010                     2
# 4  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
test_data.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#      Actual CTC
# 0  71406.576531
# 1  68005.870631
# 2  76764.020277
# 3  82092.386880
# 4  73878.097729

# %% [markdown]
# #### Analysing and understanding the dataset (test and data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   int64
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 83.8+ KB

# %%
data.describe()
# Out:
#        Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# count   1338.000000           1338.000000       1338.000000   1338.000000
# mean   55581.762332              2.525411         59.890882     39.207025
# std     6685.600553              1.123502         14.894696     14.049960
# min    36990.000000              1.000000         35.000000     18.000000
# 25%    50547.000000              2.000000         47.000000     27.000000
# 50%    55293.500000              3.000000         60.000000     39.000000
# 75%    60150.500000              4.000000         73.000000     51.000000
# max    77911.000000              4.000000         85.000000     64.000000
#
#                  CTC
# count    1338.000000
# mean    75459.338993
# std     12551.280263
# min     53020.319026
# 25%     66905.070033
# 50%     73112.640487
# 75%     80747.178420
# max    123416.994271

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   College_T1            1338 non-null   int64
#  4   College_T2            1338 non-null   int64
#  5   Role_Manager          1338 non-null   int64
#  6   City_Metro            1338 non-null   int64
#  7   previous CTC          1338 non-null   int64
#  8   previous job changes  1338 non-null   int64
#  9   Graduation marks      1338 non-null   int64
#  10  Exp                   1338 non-null   int64
#  11  Actual CTC            1338 non-null   float64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 125.6+ KB

# %%
test_data.describe()
# Out:
#         College_T1   College_T2  Role_Manager   City_Metro  previous CTC  \
# count  1338.000000  1338.000000   1338.000000  1338.000000   1338.000000
# mean      0.485052     0.272048      0.204783     0.505232  55581.762332
# std       0.499963     0.445181      0.403694     0.500160   6685.600553
# min       0.000000     0.000000      0.000000     0.000000  36990.000000
# 25%       0.000000     0.000000      0.000000     0.000000  50547.000000
# 50%       0.000000     0.000000      0.000000     1.000000  55293.500000
# 75%       1.000000     1.000000      0.000000     1.000000  60150.500000
# max       1.000000     1.000000      1.000000     1.000000  77911.000000
#
#        previous job changes  Graduation marks          Exp     Actual CTC
# count           1338.000000       1338.000000  1338.000000    1338.000000
# mean               2.525411         59.890882    39.207025   75459.338993
# std                1.123502         14.894696    14.049960   12551.280263
# min                1.000000         35.000000    18.000000   53020.319026
# 25%                2.000000         47.000000    27.000000   66905.070033
# 50%                3.000000         60.000000    39.000000   73112.640487
# 75%                4.000000         73.000000    51.000000   80747.178420
# max                4.000000         85.000000    64.000000  123416.994271

# %% [markdown]
# #### converting categorical variables to the numerical variables

# %%
print(data['College'].unique())
print(data['Role'].unique())
print(data['City type'].unique())
# Out:
# ['Tier 1' 'Tier 2' 'Tier 3']
# ['Manager' 'Executive']
# ['Non-Metro' 'Metro']

# %%
data = pd.concat([data, pd.get_dummies(data['College'])], axis=1)
data = pd.concat([data, pd.get_dummies(data['Role'])], axis=1)
data = pd.concat([data, pd.get_dummies(data['City type'])], axis=1)
data.drop(['College','Role','City type'], axis=1 , inplace = True)

# %%
data
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0            55523                     3                66            19
# 1            57081                     1                84            18
# 2            60347                     2                52            28
# 3            49010                     2                81            33
# 4            57879                     4                74            32
# ...            ...                   ...               ...           ...
# 1333         59661                     4                68            50
# 1334         53714                     1                67            18
# 1335         61957                     1                47            18
# 1336         53203                     3                69            21
# 1337         51820                     1                47            61
#
#                CTC  Tier 1  Tier 2  Tier 3  Executive  Manager  Metro  \
# 0     71406.576531       1       0       0          0        1      0
# 1     68005.870631       0       1       0          1        0      1
# 2     76764.020277       0       1       0          1        0      1
# 3     82092.386880       0       0       1          1        0      1
# 4     73878.097729       0       0       1          1        0      1
# ...            ...     ...     ...     ...        ...      ...    ...
# 1333  69712.403655       0       0       1          1        0      1
# 1334  69298.750099       1       0       0          1        0      0
# 1335  66397.770686       0       1       0          1        0      0
# 1336  64044.382949       1       0       0          1        0      0
# 1337  83346.060961       0       0       1          0        1      0
#
#       Non-Metro
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1333          0
# 1334          1
# 1335          1
# 1336          1
# 1337          1
#
# [1338 rows x 12 columns]

# %% [markdown]
# #### correlation

# %%
data.corr()
# Out:
#                       Previous CTC  Previous job changes  Graduation marks  \
# Previous CTC              1.000000              0.008282         -0.037170
# Previous job changes      0.008282              1.000000          0.001507
# Graduation marks         -0.037170              0.001507          1.000000
# Exp (Months)              0.117035              0.034137         -0.065412
# CTC                       0.270260              0.007518         -0.017557
# Tier 1                   -0.090043              0.037294          0.015750
# Tier 2                    0.232138              0.008599          0.010571
# Tier 3                   -0.135957             -0.052387         -0.029326
# Executive                -0.021208              0.013131         -0.014541
# Manager                   0.021208             -0.013131          0.014541
# Metro                     0.036956             -0.001568          0.018550
# Non-Metro                -0.036956              0.001568         -0.018550
#
#                       Exp (Months)       CTC    Tier 1    Tier 2    Tier 3  \
# Previous CTC              0.117035  0.270260 -0.090043  0.232138 -0.135957
# Previous job changes      0.034137  0.007518  0.037294  0.008599 -0.052387
# Graduation marks         -0.065412 -0.017557  0.015750  0.010571 -0.029326
# Exp (Months)              1.000000  0.301569  0.010716 -0.011642 -0.000407
# CTC                       0.301569  1.000000  0.165249 -0.041814 -0.149194
# Tier 1                    0.010716  0.165249  1.000000 -0.593313 -0.549730
# Tier 2                   -0.011642 -0.041814 -0.593313  1.000000 -0.346265
# Tier 3                   -0.000407 -0.149194 -0.549730 -0.346265  1.000000
# Executive                 0.025019 -0.625435  0.029292 -0.068498  0.036945
# Manager                  -0.025019  0.625435 -0.029292  0.068498 -0.036945
# Metro                    -0.020856  0.211258 -0.005669  0.017117 -0.011156
# Non-Metro                 0.020856 -0.211258  0.005669 -0.017117  0.011156
#
#                       Executive   Manager     Metro  Non-Metro
# Previous CTC          -0.021208  0.021208  0.036956  -0.036956
# Previous job changes   0.013131 -0.013131 -0.001568   0.001568
# Graduation marks      -0.014541  0.014541  0.018550  -0.018550
# Exp (Months)           0.025019 -0.025019 -0.020856   0.020856
# CTC                   -0.625435  0.625435  0.211258  -0.211258
# Tier 1                 0.029292 -0.029292 -0.005669   0.005669
# Tier 2                -0.068498  0.068498  0.017117  -0.017117
# Tier 3                 0.036945 -0.036945 -0.011156   0.011156
# Executive              1.000000 -1.000000 -0.076185   0.076185
# Manager               -1.000000  1.000000  0.076185  -0.076185
# Metro                 -0.076185  0.076185  1.000000  -1.000000
# Non-Metro              0.076185 -0.076185 -1.000000   1.000000

# %%
sns.pairplot(original_data, vars=["Previous CTC","Previous job changes","Graduation marks","Exp (Months)","CTC"])

# %%
sns.pairplot(original_data, kind="scatter", hue = "College", vars=["Previous CTC","Previous job changes","Exp (Months)","CTC"])

# %%
sns.pairplot(original_data, hue = "Role", vars=["Previous CTC","Previous job changes","Exp (Months)","CTC"])

# %%
sns.kdeplot(original_data.loc[original_data['College'] == "Tier 1", "CTC"], shade=True, color="g", label="Tier 1", alpha=.7)
sns.kdeplot(original_data.loc[original_data['College'] == "Tier 2", "CTC"], shade=True, color="deeppink", label="Tier 2", alpha=.7)
sns.kdeplot(original_data.loc[original_data['College'] == "Tier 3", "CTC"], shade=True, color="dodgerblue", label="Tier 3", alpha=.7)
plt.legend()
plt.show()

# %%
sns.kdeplot(original_data.loc[original_data['Role'] == "Manager", "CTC"], shade=True, color="g", label="Manager", alpha=.7)
sns.kdeplot(original_data.loc[original_data['Role'] == "Executive", "CTC"], shade=True, color="deeppink", label="Executive", alpha=.7)
plt.legend()
plt.show()

# %% [markdown]
# #### Histogram

# %%
viz = data[['CTC','Previous CTC']]
viz.hist()
plt.show()

# %% [markdown]
# #### Bar plot

# %%
plt.bar(original_data['College'], original_data['CTC'])
# Out:
# <BarContainer object of 1338 artists>

# %%
plt.bar(original_data['Role'], original_data['CTC'])
# Out:
# <BarContainer object of 1338 artists>

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(original_data['City type'], original_data['CTC'])

# %%
sns.boxplot(original_data['Role'], original_data['CTC'])

# %%
sns.boxplot(original_data['College'], original_data['CTC'])

# %%
sns.countplot("College", data=original_data)

# %%
sns.countplot("Role", data=original_data)

# %% [markdown]
# #### Piechart

# %%
df = original_data.groupby('Role').size()
df.plot(kind='pie', subplots=True, figsize=(8, 8), explode=[0,0.1])
plt.ylabel("")
plt.show()

# %%
df = original_data.groupby('City type').size()
df.plot(kind='pie', subplots=True, figsize=(8, 8), explode=[0,0])
plt.ylabel("")
plt.show()

# %% [markdown]
# #### Training the dataset

# %%
xtrain = data[['Exp (Months)', 'Previous CTC','Graduation marks']]
xtest = test_data[['Exp','previous CTC','Graduation marks']]

# %%
Xtrain = scaler.fit_transform(xtrain)
Xtest = scaler.fit_transform(xtest)

# %%
Ytrain = data['CTC']
Ytest = test_data['Actual CTC']

# %% [markdown]
# #### Linear regression

# %%
regr.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', regr.coef_)
print('Intercept: ', regr.intercept_)
# Out:
# Coefficients:  [3441.03416064 2992.42615749  116.02899717]
# Intercept:  75459.33899340554

# %%
Ytest_pred = regr.predict(Xtest)

# %%
Final = pd.DataFrame({'Actual CTC': Ytest, 'Predicted CTC': Ytest_pred})
print(Final)
# Out:
#         Actual CTC  Predicted CTC
# 0     71406.576531   70529.798142
# 1     68005.870631   71122.674221
# 2     76764.020277   74785.744177
# 3     82092.386880   71160.509942
# 4     73878.097729   74832.138285
# ...            ...            ...
# 1333  69712.403655   79993.392646
# 1334  69298.750099   69482.587299
# 1335  66397.770686   73017.616291
# 1336  64044.382949   70004.384816
# 1337  83346.060961   79013.918670
#
# [1338 rows x 2 columns]

# %%
MSE = np.mean((Ytest_pred - Ytest) ** 2)
print("Residual sum of squares: %.2f" % MSE)
print('Root Mean Squared Error:', np.sqrt(MSE))
print('Variance score: %.2f' % regr.score(Xtest, Ytest))
print("R2 : ",r2_score(Ytest, Ytest_pred))
# Out:
# Residual sum of squares: 134275913.60
# Root Mean Squared Error: 11587.748426638562
# Variance score: 0.15
# R2 :  0.147004445716859

# %%
ax1 = sns.distplot(Ytest, hist=False, color="r", label="Actual CTC")
sns.distplot(Ytest_pred, hist=False, color="b", label="Predicted CTC" , ax=ax1)
plt.legend()
plt.show()

# %%
sns.regplot(Ytest, Ytest_pred)

# %% [markdown]
# #### Output

# %%
Output = pd.concat([test_data, pd.DataFrame(Ytest_pred, columns=["Predicted CTC"])], axis=1)

# %%
file_name = 'Test_Data.xlsx'
Output.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
